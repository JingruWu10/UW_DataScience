# %% [markdown]
# # Automated Sensing of Red vs. White Wine
# _... with the cheapest sensor possible_

# %% [markdown]
# #### Data Science 420 BB
# #### University of Washington Professional & Continuing Education
#
# #### Homework 1: Low-cost Sensor
# #### Leo Salemann, 4/11/18

# %% [markdown]
# # LOAD DATA

# %%
file <- "./RedWhiteWine.csv"
all_data <- read.csv(file, header=TRUE, sep=",", stringsAsFactors = FALSE)

# If the target column, say column class, is numerical, you need to convert it to factors in R for classification problem
all_data$Class <- factor(all_data$Class)
head(all_data)
dim(all_data)
# Out:
#   fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1  7.4          0.70             0.00        1.9            0.076
# 2  7.8          0.88             0.00        2.6            0.098
# 3  7.8          0.76             0.04        2.3            0.092
# 4 11.2          0.28             0.56        1.9            0.075
# 5  7.4          0.70             0.00        1.9            0.076
# 6  7.4          0.66             0.00        1.8            0.075
#   free.sulfur.dioxide total.sulfur.dioxide density pH   sulphates alcohol
# 1 11                  34                   0.9978  3.51 0.56      9.4
# 2 25                  67                   0.9968  3.20 0.68      9.8
# 3 15                  54                   0.9970  3.26 0.65      9.8
# 4 17                  60                   0.9980  3.16 0.58      9.8
# 5 11                  34                   0.9978  3.51 0.56      9.4
# 6 13                  40                   0.9978  3.51 0.56      9.4
#   quality Class
# 1 5       1
# 2 5       1
# 3 5       1
# 4 6       1
# 5 5       1
# 6 5       1
# [1] 6497   13

# %% [markdown]
# ## Redefine Class 1 as Red and 0 as White

# %% [raw]
# all_data$Color <- ifelse(all_data$Class ==1,'Red','White')
# all_data$Color <- factor(all_data$Color)
# head(all_data)

# %% [markdown]
# ## Drop the quality attribute

# %%
library("dplyr")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
all_data2 = select(all_data, -quality)
head(all_data2)
# Out:
#   fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1  7.4          0.70             0.00        1.9            0.076
# 2  7.8          0.88             0.00        2.6            0.098
# 3  7.8          0.76             0.04        2.3            0.092
# 4 11.2          0.28             0.56        1.9            0.075
# 5  7.4          0.70             0.00        1.9            0.076
# 6  7.4          0.66             0.00        1.8            0.075
#   free.sulfur.dioxide total.sulfur.dioxide density pH   sulphates alcohol Class
# 1 11                  34                   0.9978  3.51 0.56      9.4     1
# 2 25                  67                   0.9968  3.20 0.68      9.8     1
# 3 15                  54                   0.9970  3.26 0.65      9.8     1
# 4 17                  60                   0.9980  3.16 0.58      9.8     1
# 5 11                  34                   0.9978  3.51 0.56      9.4     1
# 6 13                  40                   0.9978  3.51 0.56      9.4     1

# %% [markdown]
# ## Reduce to the features our sensor technology can acutually support

# %%
data = select(all_data, fixed.acidity, volatile.acidity, citric.acid, residual.sugar, chlorides, density, Class)
# data = select(all_data, fixed.acidity, volatile.acidity, citric.acid, residual.sugar, chlorides, density, Class, Color)
head(data)
dim(data)
summary(data)
# Out:
#   fixed.acidity volatile.acidity citric.acid residual.sugar chlorides density
# 1  7.4          0.70             0.00        1.9            0.076     0.9978
# 2  7.8          0.88             0.00        2.6            0.098     0.9968
# 3  7.8          0.76             0.04        2.3            0.092     0.9970
# 4 11.2          0.28             0.56        1.9            0.075     0.9980
# 5  7.4          0.70             0.00        1.9            0.076     0.9978
# 6  7.4          0.66             0.00        1.8            0.075     0.9978
#   Class
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1
# 6 1
# [1] 6497    7
#  fixed.acidity    volatile.acidity  citric.acid     residual.sugar
#  Min.   : 3.800   Min.   :0.0800   Min.   :0.0000   Min.   : 0.600
#  1st Qu.: 6.400   1st Qu.:0.2300   1st Qu.:0.2500   1st Qu.: 1.800
#  Median : 7.000   Median :0.2900   Median :0.3100   Median : 3.000
#  Mean   : 7.215   Mean   :0.3397   Mean   :0.3186   Mean   : 5.443
#  3rd Qu.: 7.700   3rd Qu.:0.4000   3rd Qu.:0.3900   3rd Qu.: 8.100
#  Max.   :15.900   Max.   :1.5800   Max.   :1.6600   Max.   :65.800
#    chlorides          density       Class
#  Min.   :0.00900   Min.   :0.9871   0:4898
#  1st Qu.:0.03800   1st Qu.:0.9923   1:1599
#  Median :0.04700   Median :0.9949
#  Mean   :0.05603   Mean   :0.9947
#  3rd Qu.:0.06500   3rd Qu.:0.9970
#  Max.   :0.61100   Max.   :1.0390

# %% [markdown]
# # BUILD A NAIVE BAYES CLASSIFIER

# %%
install.packages("naivebayes")
library(naivebayes)
# install.packages("pROC")
# library(pROC)
# Out:
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/3.2’
# (as ‘lib’ is unspecified)
# The downloaded source packages are in
# 	‘/tmp/RtmpniIXRi/downloaded_packages’

# %% [markdown]
# # Make a function that quickly tests NBC accuracy

# %%
test_nbc_accuracy <- function(df, plot=FALSE) {
 
    # df = select(df, -Color)
    # split into test and training sets
    nrows <- nrow(df)
    smp_size <- floor(0.75 * nrows)

    set.seed(42)
    train_ind <- sample(seq_len(nrows), size = smp_size)
    
    train <- df[train_ind, ]
    test <- df[-train_ind, ]
    
    # create the Naive Bayes Classifer (nbc)
    nbc <- naive_bayes(Class ~ ., data = train)
    
    if (plot) {
        plot(nbc)
    }
    # Make a prediction & test accuracy
    test_pred <- predict(nbc, test,type = "prob")
    test_pred <- predict(nbc, test)
    
    ### junky debug stuff
    # print(head (test_pred))
    ### junky debug stuff
    accuracy <- sum(test[,"Class"]==test_pred)/length(test_pred)
    print(paste("Accuracy=", round(accuracy*100,2), "%", sep=""))

    # try to do the AUC
    # print(paste("AUC=", auc(test_pred, df$Class)))

}

# %% [markdown]
# ## Classification Accuracy, All Attributes

# %%
test_nbc_accuracy(all_data)
test_nbc_accuracy(all_data2)
# Out:
# [1] "Accuracy=97.91%"
# [1] "Accuracy=97.97%"

# %% [markdown]
# ## Classification Accuracy, Sensor-supported Attributes

# %%
test_nbc_accuracy(data)
# Out:
# [1] "Accuracy=94.65%"

# %% [markdown]
# # OPTIMISING ATTRIBUTES

# %% [markdown]
# ## Simplest Case First: Single-Feature Sensor
# Presumably, the cheapest sensor we can design and build is one that samples only a single paremeter. Given our small search space (6 features) and reusable function, we can do a quick check in six lines of code

# %%
head(all_data, 2)
# Out:
#   fixed.acidity volatile.acidity citric.acid residual.sugar chlorides
# 1 7.4           0.70             0           1.9            0.076
# 2 7.8           0.88             0           2.6            0.098
#   free.sulfur.dioxide total.sulfur.dioxide density pH   sulphates alcohol
# 1 11                  34                   0.9978  3.51 0.56      9.4
# 2 25                  67                   0.9968  3.20 0.68      9.8
#   quality Class
# 1 5       1
# 2 5       1

# %%
test_nbc_accuracy(select(all_data, fixed.acidity, Class))
test_nbc_accuracy(select(all_data, volatile.acidity, Class))
test_nbc_accuracy(select(all_data, citric.acid, Class))
test_nbc_accuracy(select(all_data, residual.sugar, Class))
test_nbc_accuracy(select(all_data, chlorides, Class))
test_nbc_accuracy(select(all_data, free.sulfur.dioxide, Class))
test_nbc_accuracy(select(all_data, total.sulfur.dioxide, Class))
test_nbc_accuracy(select(all_data, density, Class))
test_nbc_accuracy(select(all_data, pH, Class))
test_nbc_accuracy(select(all_data, sulphates, Class))
test_nbc_accuracy(select(all_data, alcohol, Class))
# Out:
# [1] "Accuracy=80.8%"
# [1] "Accuracy=86.22%"
# [1] "Accuracy=79.57%"
# [1] "Accuracy=67.51%"
# [1] "Accuracy=79.69%"
# [1] "Accuracy=82.52%"
# [1] "Accuracy=93.11%"
# [1] "Accuracy=72.37%"
# [1] "Accuracy=74.22%"
# [1] "Accuracy=78.71%"
# [1] "Accuracy=74.46%"

# %% [markdown]
# Okay, so that didn't rurn out well; but it was a quick test and we sitll learned something.

# %% [markdown]
# ## Plot the NBC and Use Some Human Intuition

# %%
options(repr.plot.width=3, repr.plot.height=3)

# %%
# test_nbc_accuracy(data, plot=TRUE)
test_nbc_accuracy(all_data, plot=TRUE)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# [1] "Accuracy=97.91%"
# plot without title

# %% [markdown]
# Reviewing the plots, ranked by least similar to most similar
# - volatile.acidity
# - chlorieds
# - fixed.acidity
# - density
# - residual.sugar
# - citric.acid
#
# Let's run another battery of tests, trimming the features off from the bottom and working our way up.

# %% [raw]
# head(data, 3)
# head(select(data, -one_of(c('fixed.acidity', 'volatile.acidity')), 3))

# %%
test_nbc_accuracy(select(data, -one_of(c('citric.acid'))))

test_nbc_accuracy(select(data, -one_of(c('citric.acid', 
                                         'residual.sugar'))))

test_nbc_accuracy(select(data, -one_of(c('citric.acid', 
                                         'residual.sugar',
                                         'density'))))

test_nbc_accuracy(select(data, -one_of(c('citric.acid', 
                                         'residual.sugar',
                                         'density',
                                         'fixed.acidity'))))
# Out:
# [1] "Accuracy=94.65%"
# [1] "Accuracy=91.14%"
# [1] "Accuracy=90.65%"
# [1] "Accuracy=88.68%"

# %% [markdown]
# Reviewing the plots, ranked by least similar to most similar for ALL params
# - total.sulfur.disoxide
# - volatile.acidity
# - fixed.acidity
# - chlorides
# - residual.sugar
# - free.sulfur.dioxide
# - density
# - citric.acid
# - pH

# %%
test_nbc_accuracy(select(all_data, -one_of(c('pH'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density','free.sulfur.dioxide'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density','free.sulfur.dioxide',
                                            'residual.sugar'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density','free.sulfur.dioxide',
                                            'residual.sugar','chlorides'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density','free.sulfur.dioxide',
                                            'residual.sugar','chlorides','fixed.acidity'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density','free.sulfur.dioxide',
                                            'residual.sugar','chlorides','fixed.acidity',
                                             'volatile.acidity'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','density','free.sulfur.dioxide',
                                            'residual.sugar','chlorides','fixed.acidity',
                                             'volatile.acidity','total.sulfur.dioxide'))))
# Out:
# [1] "Accuracy=97.29%"
# [1] "Accuracy=97.42%"
# [1] "Accuracy=96.18%"
# [1] "Accuracy=96.8%"
# [1] "Accuracy=96.43%"
# [1] "Accuracy=96.8%"
# [1] "Accuracy=96.49%"
# [1] "Accuracy=95.02%"
# [1] "Accuracy=79.38%"

# %%
### RESUME HERE ####

# %%
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','free.sulfur.dioxide'))))
test_nbc_accuracy(select(all_data, -one_of(c('pH','citric.acid','free.sulfur.dioxide'))))
# Out:
# [1] "Accuracy=97.42%"
# [1] "Accuracy=97.66%"
# [1] "Accuracy=97.66%"

# %% [markdown]
# We're still not able to beat the accuracy from keeping all the features.  Time to pull out the big guns.

# %% [markdown]
# ## Load Caret from github

# %%
install.packages("devtools")
devtools::install_github('topepo/caret/pkg/caret')
# Out:
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/3.2’
# (as ‘lib’ is unspecified)
# The downloaded source packages are in
# 	‘/tmp/RtmpniIXRi/downloaded_packages’
# Skipping install of 'caret' from a github remote, the SHA1 (63c51c19) has not changed since last install.
#   Use `force = TRUE` to force installation

# %% [markdown]
# ## Try a Feature Plot

# %%
install.packages("AppliedPredictiveModeling")
library(AppliedPredictiveModeling)
transparentTheme(trans = .4)
library(caret)
# Out:
# Installing package into ‘/home/vagrant/R/x86_64-pc-linux-gnu-library/3.2’
# (as ‘lib’ is unspecified)
# The downloaded source packages are in
# 	‘/tmp/RtmpniIXRi/downloaded_packages’
# Loading required package: ggplot2
# Warning message:
# “replacing previous import by ‘plyr::ddply’ when loading ‘caret’”Warning message:
# “replacing previous import by ‘tidyr::%>%’ when loading ‘broom’”Warning message:
# “replacing previous import by ‘tidyr::gather’ when loading ‘broom’”Warning message:
# “replacing previous import by ‘tidyr::spread’ when loading ‘broom’”Warning message:
# “replacing previous import by ‘rlang::!!’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::expr’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::f_lhs’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::f_rhs’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::is_empty’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::lang’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::na_dbl’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::names2’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::quos’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::sym’ when loading ‘recipes’”Warning message:
# “replacing previous import by ‘rlang::syms’ when loading ‘recipes’”

# %%
options(repr.plot.width=12, repr.plot.height=12)
featurePlot(x = data[, 1:6], 
            y = data$Class, 
            plot = "pairs",
            ## Add a key at the top
            auto.key = list(columns = 3))
# Out:
# Warning message in draw.key(simpleKey(...), draw = FALSE):
# “not enough rows for columns”
# plot without title

# %% [markdown]
# Looking for "minimal overlaps" (e.g. where we can see as much blue and red simultaneosly), let's try comgbining  residual.sugar, citric acid, and volatile acidiity

# %%
test_nbc_accuracy(data)
test_nbc_accuracy(select(data, residual.sugar, citric.acid, volatile.acidity, Class))
# Out:
# [1] "Accuracy=94.65%"
# [1] "Accuracy=89.42%"

# %% [markdown]
# # ----------------------------------------------------------

# %%
    df = data
    plot = TRUE

    # split into test and training sets
    nrows <- nrow(df)
    smp_size <- floor(0.75 * nrows)

    set.seed(8720885)
    train_ind <- sample(seq_len(nrows), size = smp_size)
    
    train <- df[train_ind, ]
    test <- df[-train_ind, ]
    
    # create the Naive Bayes Classifer (nbc)
    nbc <- naive_bayes(Class ~ ., data = train)
    
    if (plot) {
        plot(nbc)
    }
    # Make a prediction & test accuracy
    test_pred <- predict(nbc, test,type = "prob")
    
    ### junky debug stuff
    # print(head (test_pred))
    ### junky debug stuff
    accuracy <- sum(test[,"Class"]==test_pred)/length(test_pred)
    print(paste("Accuracy=", round(accuracy*100,2), "%", sep=""))

    # try to do the AUC
    # print(paste("AUC=", auc(test_pred, df$Class)))
    # as.numeric(performance(ROCRpred, "auc")@y.values)

# %%
Maybe try [this instead](http://blog.revolutionanalytics.com/2016/11/calculating-auc.html)

# %%
Maybe try [this instead](https://www.r-bloggers.com/illustrated-guide-to-roc-and-auc/)

# %%
colnames(test_pred) <- c("White", "Red")
head(test_pred, 3)
head(test_pred[,'White'], 3)
head(test_pred[,'Red'], 3)

# %%
whitevec <- ifelse(test_pred[,'White'] > test_pred[,'Red'] , 1, 0)
redvec   <- ifelse(test_pred[,'Red'] > test_pred[,'White'] , 1, 0)
head(whitevec, 3)
head(redvec, 3)



predvec <- ifelse(pred=="Lost", 1, 0)
realvec <- ifelse(realResults=="Lost", 1, 0)
pr <- prediction(predvec, realvec)

# %% [markdown]
# ## Run some Tests

# %% [markdown]
# ## Run some Tests

# %% [markdown]
# ## Run some Tests

# %% [markdown]
# ## Assume the cheapest solution is a single sensor.  Try all the single-feature options.

# %% [markdown]
# ## Run some Tests

# %% [markdown]
# Yeah, that didn't work; but it was a quick test, and would have led to a cheaper product if it did.  Was still worth a shot.

# %% [markdown]
# ## Do some plots

# %%
test_nbc_accuracy(data, plot=TRUE)

# %%
# Try Dropping chlorides, since it's the opposite of residual sugar

# %%
test_data = select(data, -chlorides)
head(test_data)

# %%
test_nbc_accuracy(test_data)

# %%
# Try Dropping Volatile acidity

# %%
test_data = select(test_data, -volatile.acidity)
head(test_data)

# %%
test_nbc_accuracy(test_data)
test_nbc_accuracy(data)
test_nbc_accuracy(all_data)
test_nbc_accuracy(select(all_data, -quality))

# %%
auc(test_data$, test_data$Class)

# %% [markdown]
# # ====================< JUNK >=====================

# %% [markdown]
# # Create a Naive Bayes Model, Try a Prediction

# %%
nrows <- nrow(data)
smp_size <- floor(0.75 * nrows)

## set the seed to make your partition reproductible
set.seed(8720885)
train_ind <- sample(seq_len(nrows), size = smp_size)

# %%
train <- data[train_ind, ]
test <- data[-train_ind, ]

# %%
options(repr.plot.width=4, repr.plot.height=4)
plot(nbc)

# %%
install.packages("naivebayes")
library(naivebayes)
nbc <- naive_bayes(Class ~ ., data = train)
plot(nbc)

# %%
# Predict the test data
test_pred <- predict(nbc, test,type = "prob")

accuracy <- sum(test[,"Class"]==test_pred)/length(test_pred)
print(paste("Accuracy=", round(accuracy*100,2), "%", sep=""))

# %% [markdown]
# ## Pull out a handy plotting function from last quarter

# %%
require(ggplot2)
plot.density = function(df, col, xlabel, title) {
    ggplot(df, aes(col)) + 
          geom_bar() + 
          xlab(xlabel) + 
          ggtitle(title) + 
          theme(plot.title = element_text(hjust = 0.5, size=20, face="bold"),
               axis.title.x = element_text(size=15))
}

# %%
options(repr.plot.width=12, repr.plot.height=4)
plot.density(data, data$Class, "1 = Red?, 2 = White?", "Wine Color")

# %% [markdown]
# ## Try some Fancy Matrix Plotting

# %%
require(GGally)

plot.matrix = function(df, cols){
    options(repr.plot.width=8, repr.plot.height=8)
    ggpairs(data=df,
            columns=cols,
            upper = list(continuous = "density"),
            lower = list(continuous = "density"),
            cardinality_threshold = 130)
}

# %%
plot.matrix(data, c(1:6,7))

# %%
prediction = predict(nbc, test, type= "prob")
head(prediction)
