# %% [markdown]
# # Data Science 410 BB
# ## Univerity of Washington Professional & Continuing Education
#
# ### Homework N: title
# ### Leo Salemann
# ### date

# %% [markdown]
# # ALIGNING TO THE ACTUAL ASSINGMENT
# - heating load & cooling load already given as target vars
# - find THREE interesting relationships
#   - Two-Hump Density Plot
#   - Roof Area
#   - Overall Height
# - [info from the aardvark site](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency)
# - Submit ONE r SCRIPT, html  form, wiht ...
#   - 3 key points, each having
#     - Clear engligh statment
#     - Plots and/or tables to support colusion
#     - More plots for data ivestigation

# %% [markdown]
# # CLEANER NOTES
#
# ## The Punchline
#
# ## The Flow
#
# Overview
# - Table inspection to find the key vars (Heating/cooling loads)
# - Density plots to see the 2 humps
# - pairs plot for other vars (Roof Area, Height, Sfc Aea)
# - Contour scatter plots to find 3 clusters
# - Violin plots with the long skinny tails (heating vs. Sfc Area)
# - Big Reveal(s)
#   - When comes to to Sfc area, 3 clusters
#   - The strongest correlations are roof area & overall height, but need more values.
#
#
# Finding the Key Variable(s)
# - Basic table inspections
# - Density Plots - 2-ish humps
#
#
# Pairs Plot
# - Correlations point to the vars of interest
#   - Overall.Height, Roof.Area
#   - Histograms have a story to tell
#     - Only two roof heights, larger spread of Wall Area
#     - Uniform distro of otientation, Glazing Area Sfc Area
#   - Interesting Plots
#     - Wall area, colored by height
#     - Relative Cmpactness, Sfc ARea, Wall Area
#       - Opportunites for clusters & contours
#       - Correlation is meh (0.4, 0.6)
#         - Maybe need to filter by heigh tone at a time?
#   - Also worth exploring(?)
#
# Pairs Plot V2
# - Coloring by glazing area teases things apart a bit
# - Could color by area, size by height, shape by wall area
#
#
#
# ## The Rest of it

# %% [markdown]
# # BIG WAD OF NOTES
#
# What's the big reveal?
# - Things tend to cluster around overall height.
#   - Heating Load v. Wall.Area
#   - Heating Load v. Surface Area
#   - Heating Load v. Relative cmpacness
#       - (looks like flipside of sfc area)
#
# Using my latest toys ...
# - Histo/Cor helps narrow it down alot
# - collapse some pairs (only Relatiive.Compsctess, Only Heatin load
# - The most intriguing one is Heating Load v. RelComact
#   - Heating Load v. Roof Area kinda neat, too
#
# How did we figure it out?
# - basic data checks
# - pairs plot, colorize on realtive height
# - "Zoom in" to key params
#
# Other stuff
# - Heating Load v. Surface Area, splits on height & glazing
#   - color based on glazing
#   - size or shape based on height
#   - The countoured dot plot brings ths out too
#     - suggests a 3rd cluster: Higest heat laod, medum sfc area
# - Violin plot, heating v. Roof Area
#   - culsters based on ehight (1 short, 3 tall)
# - Violin plot Load vs. Sfc Area
#   - follows the dot plot, basicaly.
#
# - Density Plot, two humps.
#   - but just the slightes dent/bump on the right-side one.
#
#
# - More ideas ...
#   - Can use Glazing.Area.Distribution for clean integers.
#   - The ultimate mega-plot
#     - 5 shapes (Glazing.Area.Distro)
#     - 4 colors (Glazing.Area)
#     - 2 sizes (Height)
#   - Also keep stepping thru the class notebook
#
# - Glazing Area ...
#   - Area: 0, 0.1, 0.25, 0.4
#   - Area.Disribution 0, 1, 2, 3, 4, 5
# - How do we tell a story? ....
#   - Find the "load" vars
#     - Do the denisty plot (2 humps)
#   - Pairs plot, colors, size or shape, look for patterns
#   - Pick out the Heting Load vs. Sfc Area,
#     - or Relative Comapctness
#     - or Wall ARea
#   - Do contoured dot plots ... find 3 clusters
#   - Move on to violin plots ...
#     - can pick out the 3 clusters
#     - everthing has a "low skinny tail" (one outliner?)
#       - Maybe violin + box plot
